# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
loss_raw = pd.read_csv('E:/my-whitecaps/code/organized/model/test/raw_test/training_statistics_test.csv')
loss_vgg = pd.read_csv('E:/my-whitecaps/code/organized/model/test/vgg_test/training_statistics_test.csv')
loss_resnet = pd.read_csv('E:/my-whitecaps/code/organized/model/test/resnet50_test/training_statistics_test.csv')

# %%
loss_raw
# Out:
#     Unnamed: 0              lr_rate_list  train_loss_list  valid_loss_list  \
# 0            0                   [0.005]         0.970888         0.616219
# 1            1                   [0.005]         0.560422         0.493418
# 2            2                   [0.005]         0.510329         0.489620
# 3            3                   [0.005]         0.291726         0.457201
# 4            4                   [0.005]         0.309122         0.460277
# ..         ...                       ...              ...              ...
# 95          95  [2.5600000000000015e-09]         0.182052         0.278303
# 96          96  [2.5600000000000015e-09]         0.178303         0.265689
# 97          97  [2.5600000000000015e-09]         0.236016         0.280452
# 98          98  [2.5600000000000015e-09]         0.160875         0.276435
# 99          99  [2.5600000000000015e-09]         0.260506         0.273536
#
#     dice_score_list
# 0          0.461300
# 1          0.557968
# ...

# %%
lr_rate_list_raw = loss_raw['lr_rate_list'].values
lr_rate_list_vgg = loss_vgg['lr_rate_list'].values
lr_rate_list_res = loss_resnet['lr_rate_list'].values

# %%
from ast import literal_eval
plt.figure(figsize=(8,8))
plt.axes(yscale="log")
plt.plot([literal_eval(i) for i in lr_rate_list_raw],linestyle='-',linewidth = 3,color='k')
plt.plot([literal_eval(i) for i in lr_rate_list_vgg],linestyle='-.',linewidth = 3,color='k')
plt.plot([literal_eval(i) for i in lr_rate_list_res],linestyle='--',linewidth = 3,color='k')

font = {'family' : 'Times New Roman', 
        'weight' : 'normal', 
        'size' : 32}
plt.xlabel('Epoch', font)
plt.ylabel('learing rate during training', font)
plt.xticks(fontproperties='Times New Roman', size = 32)
plt.yticks(fontproperties='Times New Roman', size = 32)
plt.grid()
font_legend1 = {'family' : 'Times New Roman', 
        'weight' : 'normal', 
        'size' : 20}
plt.legend(['UNet Raw','VGG16','Resnet50'],prop = font_legend1)
plt.savefig('learn_rat_compare.png',bbox_inches='tight')

# %%
plt.plot(loss_raw['dice_score_list'])
plt.plot(loss_vgg['dice_score_list'])
plt.plot(loss_resnet['dice_score_list'])

# %%
train_loss_raw = loss_raw['train_loss_list']
train_loss_vgg = loss_vgg['train_loss_list']
train_loss_resnet50 = loss_resnet['train_loss_list']

# %%
train_loss_raw_rm = np.convolve(train_loss_raw, np.ones(30)/30, mode='valid')
train_loss_vgg_rm = np.convolve(train_loss_vgg, np.ones(30)/30, mode='valid')
train_loss_res_rm = np.convolve(train_loss_resnet50, np.ones(30)/30, mode='valid')
plt.plot(train_loss_raw_rm, 'g')
plt.plot(train_loss_vgg_rm, 'r')
plt.plot(train_loss_res_rm, 'b')

# %%
acc_raw_train = pd.read_csv('E:/my-whitecaps/code/organized/model/test/raw_test_Accuracy_train.csv')
acc_vgg_train = pd.read_csv('E:/my-whitecaps/code/organized/model/test/vgg_test_Accuracy_train.csv')
acc_res_train = pd.read_csv('E:/my-whitecaps/code/organized/model/test/resnet50_test_Accuracy_train.csv')

# %%
acc_raw_valid = pd.read_csv('E:/my-whitecaps/code/organized/model/test/raw_test_Accuracy_validation.csv')
acc_vgg_valid = pd.read_csv('E:/my-whitecaps/code/organized/model/test/vgg_test_Accuracy_validation.csv')
acc_res_valid = pd.read_csv('E:/my-whitecaps/code/organized/model/test/resnet50_test_Accuracy_validation.csv')

# %%
prec_raw_train = pd.read_csv('E:/my-whitecaps/code/organized/model/test/raw_test_Precision_train.csv')
prec_vgg_train = pd.read_csv('E:/my-whitecaps/code/organized/model/test/vgg_test_Precision_train.csv')
prec_res_train = pd.read_csv('E:/my-whitecaps/code/organized/model/test/resnet50_test_Precision_train.csv')

prec_raw_valid = pd.read_csv('E:/my-whitecaps/code/organized/model/test/raw_test_Precision_validation.csv')
prec_vgg_valid = pd.read_csv('E:/my-whitecaps/code/organized/model/test/vgg_test_Precision_validation.csv')
prec_res_valid = pd.read_csv('E:/my-whitecaps/code/organized/model/test/resnet50_test_Precision_validation.csv')

# %%
recall_raw_train = pd.read_csv('E:/my-whitecaps/code/organized/model/test/raw_test_Recall_train.csv')
recall_vgg_train = pd.read_csv('E:/my-whitecaps/code/organized/model/test/vgg_test_Recall_train.csv')
recall_res_train = pd.read_csv('E:/my-whitecaps/code/organized/model/test/resnet50_test_Recall_train.csv')

recall_raw_valid = pd.read_csv('E:/my-whitecaps/code/organized/model/test/raw_test_Recall_validation.csv')
recall_vgg_valid = pd.read_csv('E:/my-whitecaps/code/organized/model/test/vgg_test_Recall_validation.csv')
recall_res_valid = pd.read_csv('E:/my-whitecaps/code/organized/model/test/resnet50_test_Recall_validation.csv')

# %%
speci_raw_train = pd.read_csv('E:/my-whitecaps/code/organized/model/test/raw_test_Specificity_train.csv')
speci_vgg_train = pd.read_csv('E:/my-whitecaps/code/organized/model/test/vgg_test_Specificity_train.csv')
speci_res_train = pd.read_csv('E:/my-whitecaps/code/organized/model/test/resnet50_test_Specificity_train.csv')

speci_raw_valid = pd.read_csv('E:/my-whitecaps/code/organized/model/test/raw_test_Specificity_validation.csv')
speci_vgg_valid = pd.read_csv('E:/my-whitecaps/code/organized/model/test/vgg_test_Specificity_validation.csv')
speci_res_valid = pd.read_csv('E:/my-whitecaps/code/organized/model/test/resnet50_test_Specificity_validation.csv')

# %%
print(max(prec_raw_valid['Value'].values))
print(max(prec_vgg_valid['Value'].values))
print(max(prec_res_valid['Value'].values))
# Out:
# 0.8704612851142883
# 0.9110409021377563
# 0.886127233505249

# %%
c_raw = ((1-recall_raw_valid['Value'].values)*(1-speci_raw_valid['Value'].values)*prec_raw_valid['Value'].values)/((1-prec_raw_valid['Value'].values)*speci_raw_valid['Value'].values*recall_raw_valid['Value'].values)
c_vgg = ((1-recall_vgg_valid['Value'].values)*(1-speci_vgg_valid['Value'].values)*prec_vgg_valid['Value'].values)/((1-prec_vgg_valid['Value'].values)*speci_vgg_valid['Value'].values*recall_vgg_valid['Value'].values)
c_res = ((1-recall_res_valid['Value'].values)*(1-speci_res_valid['Value'].values)*prec_res_valid['Value'].values)/((1-prec_res_valid['Value'].values)*speci_res_valid['Value'].values*recall_res_valid['Value'].values)

# %%
print(max(1/(1+c_raw)))
print(max(1/(1+c_vgg)))
print(max(1/(1+c_res)))
# Out:
# 0.9978130589406402
# 0.9980625999385565
# 0.9982178663019003

# %%
f1_raw_train = pd.read_csv("E:/my-whitecaps/code/organized/model/test/raw_test_F1 score_train.csv")
f1_vgg_train = pd.read_csv("E:/my-whitecaps/code/organized/model/test/vgg_test_F1 score_train.csv")
f1_res_train = pd.read_csv("E:/my-whitecaps/code/organized/model/test/resnet50_test_F1 score_train.csv")

f1_raw_valid = pd.read_csv("E:/my-whitecaps/code/organized/model/test/raw_test_F1 score_validation.csv")
f1_vgg_valid = pd.read_csv("E:/my-whitecaps/code/organized/model/test/vgg_test_F1 score_validation.csv")
f1_res_valid = pd.read_csv("E:/my-whitecaps/code/organized/model/test/resnet50_test_F1 score_validation.csv")

# %%
f1_raw_valid_rm = np.convolve(f1_raw_valid['Value'].values, np.ones(10)/10, mode='valid')
f1_vgg_valid_rm = np.convolve(f1_vgg_valid['Value'].values, np.ones(10)/10, mode='valid')
f1_res_valid_rm = np.convolve(f1_res_valid['Value'].values[5:], np.ones(10)/10, mode='valid')

f1_raw_train_rm = np.convolve(f1_raw_train['Value'].values, np.ones(10)/10, mode='valid')
f1_vgg_train_rm = np.convolve(f1_vgg_train['Value'].values, np.ones(10)/10, mode='valid')
f1_res_train_rm = np.convolve(f1_res_train['Value'].values[5:], np.ones(10)/10, mode='valid')

plt.figure(figsize=(10,8))
# plt.plot(f1_raw_valid['Value'].values, linewidth=2, alpha=0.3, linestyle='--', color='k')
# plt.plot(f1_vgg_valid['Value'].values, linewidth=2, alpha=0.3, linestyle='--', color='k')
# plt.plot(f1_res_valid['Value'].values, linewidth=2, alpha=0.3, linestyle='--', color='k')
plt.plot(f1_raw_valid_rm, linewidth=3, color='orange', label='Raw Unet validation')
plt.plot(f1_vgg_valid_rm, linewidth=3, color='blue', label='Vgg validation')
plt.plot(f1_res_valid_rm, linewidth=3, color='green', label='Resnet validation')

plt.plot(f1_raw_train_rm, linewidth=3, color='orange', linestyle='-.',label='Raw Unet train')
plt.plot(f1_vgg_train_rm, linewidth=3, color='blue', linestyle='-.',label='Vgg train')
plt.plot(f1_res_train_rm, linewidth=3, color='green', linestyle='-.',label='Resnet train')
font = {'family' : 'Times New Roman', 
        'weight' : 'normal', 
        'size' : 32}
plt.xlabel('Epoch', font)
plt.ylabel('F1 score', font)
plt.xticks(fontproperties='Times New Roman', size = 32)
plt.yticks(fontproperties='Times New Roman', size = 32)

font_legend1 = {'family' : 'Times New Roman', 
        'weight' : 'normal', 
        'size' : 20}

plt.legend(prop = font_legend1)
plt.grid()
plt.savefig('f1_compare.png',bbox_inches='tight')

# %%
prec_raw_train = pd.read_csv("E:/my-whitecaps/code/organized/model/test/raw_test_Precision_train.csv")
prec_vgg_train = pd.read_csv("E:/my-whitecaps/code/organized/model/test/vgg_test_Precision_train.csv")
prec_res_train = pd.read_csv("E:/my-whitecaps/code/organized/model/test/resnet50_test_Precision_train.csv")

prec_raw_valid = pd.read_csv("E:/my-whitecaps/code/organized/model/test/raw_test_Precision_validation.csv")
prec_vgg_valid = pd.read_csv("E:/my-whitecaps/code/organized/model/test/vgg_test_Precision_validation.csv")
prec_res_valid = pd.read_csv("E:/my-whitecaps/code/organized/model/test/resnet50_test_Precision_validation.csv")

# %%
prec_raw_valid_rm = np.convolve(prec_raw_valid['Value'].values, np.ones(10)/10, mode='valid')
prec_vgg_valid_rm = np.convolve(prec_vgg_valid['Value'].values, np.ones(10)/10, mode='valid')
prec_res_valid_rm = np.convolve(prec_res_valid['Value'].values[5:], np.ones(10)/10, mode='valid')

prec_raw_train_rm = np.convolve(prec_raw_train['Value'].values, np.ones(10)/10, mode='valid')
prec_vgg_train_rm = np.convolve(prec_vgg_train['Value'].values, np.ones(10)/10, mode='valid')
prec_res_train_rm = np.convolve(prec_res_train['Value'].values[5:], np.ones(10)/10, mode='valid')

plt.figure(figsize=(10,8))
# plt.plot(prec_raw_valid['Value'].values, linewidth=2, alpha=0.3, linestyle='--', color='k')
# plt.plot(prec_vgg_valid['Value'].values, linewidth=2, alpha=0.3, linestyle='--', color='k')
# plt.plot(prec_res_valid['Value'].values, linewidth=2, alpha=0.3, linestyle='--', color='k')
plt.plot(prec_raw_valid_rm, linewidth=3, color='orange', label='Raw Unet validation')
plt.plot(prec_vgg_valid_rm, linewidth=3, color='blue', label='Vgg validation')
plt.plot(prec_res_valid_rm, linewidth=3, color='green', label='Resnet validation')

plt.plot(prec_raw_train_rm, linewidth=3, color='orange', linestyle='-.',label='Raw Unet train')
plt.plot(prec_vgg_train_rm, linewidth=3, color='blue', linestyle='-.',label='Vgg train')
plt.plot(prec_res_train_rm, linewidth=3, color='green', linestyle='-.',label='Resnet train')
font = {'family' : 'Times New Roman', 
        'weight' : 'normal', 
        'size' : 32}
plt.xlabel('Epoch', font)
plt.ylabel('Precision', font)
plt.xticks(fontproperties='Times New Roman', size = 32)
plt.yticks(fontproperties='Times New Roman', size = 32)

font_legend1 = {'family' : 'Times New Roman', 
        'weight' : 'normal', 
        'size' : 20}

plt.legend(prop = font_legend1)
plt.grid()
plt.savefig('precision_compare.png',bbox_inches='tight')

# %%
recall_raw_train = pd.read_csv("E:/my-whitecaps/code/organized/model/test/raw_test_Recall_train.csv")
recall_vgg_train = pd.read_csv("E:/my-whitecaps/code/organized/model/test/vgg_test_Recall_train.csv")
recall_res_train = pd.read_csv("E:/my-whitecaps/code/organized/model/test/resnet50_test_Recall_train.csv")

recall_raw_valid = pd.read_csv("E:/my-whitecaps/code/organized/model/test/raw_test_Recall_validation.csv")
recall_vgg_valid = pd.read_csv("E:/my-whitecaps/code/organized/model/test/vgg_test_Recall_validation.csv")
recall_res_valid = pd.read_csv("E:/my-whitecaps/code/organized/model/test/resnet50_test_Recall_validation.csv")

# %%
recall_raw_valid_rm = np.convolve(recall_raw_valid['Value'].values, np.ones(10)/10, mode='valid')
recall_vgg_valid_rm = np.convolve(recall_vgg_valid['Value'].values, np.ones(10)/10, mode='valid')
recall_res_valid_rm = np.convolve(recall_res_valid['Value'].values[5:], np.ones(10)/10, mode='valid')

recall_raw_train_rm = np.convolve(recall_raw_train['Value'].values, np.ones(10)/10, mode='valid')
recall_vgg_train_rm = np.convolve(recall_vgg_train['Value'].values, np.ones(10)/10, mode='valid')
recall_res_train_rm = np.convolve(recall_res_train['Value'].values[5:], np.ones(10)/10, mode='valid')

plt.figure(figsize=(10,8))
# plt.plot(recall_raw_valid['Value'].values, linewidth=2, alpha=0.3, linestyle='--', color='k')
# plt.plot(recall_vgg_valid['Value'].values, linewidth=2, alpha=0.3, linestyle='--', color='k')
# plt.plot(recall_res_valid['Value'].values, linewidth=2, alpha=0.3, linestyle='--', color='k')
plt.plot(recall_raw_valid_rm, linewidth=3, color='orange', label='Raw Unet validation')
plt.plot(recall_vgg_valid_rm, linewidth=3, color='blue', label='Vgg validation')
plt.plot(recall_res_valid_rm, linewidth=3, color='green', label='Resnet validation')

plt.plot(recall_raw_train_rm, linewidth=3, color='orange', linestyle='-.',label='Raw Unet train')
plt.plot(recall_vgg_train_rm, linewidth=3, color='blue', linestyle='-.',label='Vgg train')
plt.plot(recall_res_train_rm, linewidth=3, color='green', linestyle='-.',label='Resnet train')
font = {'family' : 'Times New Roman', 
        'weight' : 'normal', 
        'size' : 32}
plt.xlabel('Epoch', font)
plt.ylabel('Recall', font)
plt.xticks(fontproperties='Times New Roman', size = 32)
plt.yticks(fontproperties='Times New Roman', size = 32)

font_legend1 = {'family' : 'Times New Roman', 
        'weight' : 'normal', 
        'size' : 20}

plt.legend(prop = font_legend1)
plt.grid()
plt.savefig('recall_compare.png',bbox_inches='tight')

# %%
train_loss_raw = loss_raw['train_loss_list']
train_loss_vgg = loss_vgg['train_loss_list']
train_loss_resnet50 = loss_resnet['train_loss_list']

valid_loss_raw = loss_raw['valid_loss_list']
valid_loss_vgg = loss_vgg['valid_loss_list']
valid_loss_resnet50 = loss_resnet['valid_loss_list']

train_loss_raw_rm = np.convolve(train_loss_raw, np.ones(10)/10, mode='valid')
train_loss_vgg_rm = np.convolve(train_loss_vgg, np.ones(10)/10, mode='valid')
train_loss_res_rm = np.convolve(train_loss_resnet50, np.ones(10)/10, mode='valid')

valid_loss_raw_rm = np.convolve(valid_loss_raw, np.ones(10)/10, mode='valid')
valid_loss_vgg_rm = np.convolve(valid_loss_vgg, np.ones(10)/10, mode='valid')
valid_loss_res_rm = np.convolve(valid_loss_resnet50, np.ones(10)/10, mode='valid')

# %%
plt.figure(figsize=(10,8))
# plt.plot(valid_loss_raw.values, linewidth=2, alpha=0.3, linestyle='--', color='k')
# plt.plot(valid_loss_vgg.values, linewidth=2, alpha=0.3, linestyle='--', color='k')
# plt.plot(valid_loss_resnet50.values, linewidth=2, alpha=0.3, linestyle='--', color='k')
plt.plot(valid_loss_raw_rm, linewidth=3, color='orange', label='Raw Unet validation')
plt.plot(valid_loss_vgg_rm, linewidth=3, color='blue', label='Vgg validation')
plt.plot(valid_loss_res_rm, linewidth=3, color='green', label='Resnet validation')

plt.plot(train_loss_raw_rm, linewidth=3, color='orange', linestyle='-.',label='Raw Unet train')
plt.plot(train_loss_vgg_rm, linewidth=3, color='blue', linestyle='-.',label='Vgg train')
plt.plot(train_loss_res_rm, linewidth=3, color='green', linestyle='-.',label='Resnet train')
font = {'family' : 'Times New Roman', 
        'weight' : 'normal', 
        'size' : 32}
plt.xlabel('Epoch', font)
plt.ylabel('Loss', font)
plt.xticks(fontproperties='Times New Roman', size = 32)
plt.yticks(fontproperties='Times New Roman', size = 32)

font_legend1 = {'family' : 'Times New Roman', 
        'weight' : 'normal', 
        'size' : 20}

plt.legend(prop = font_legend1)
plt.grid()
plt.savefig('loss_compare.png',bbox_inches='tight')
